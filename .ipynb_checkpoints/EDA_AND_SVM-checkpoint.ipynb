# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("DATA/Indian Liver Patient Dataset (ILPD).csv")

# %%
df.shape
# Out:
# (582, 11)

# %%
df.iloc[0]
# Out:
# 65          62
# Female    Male
# 0.7       10.9
# 0.1        5.5
# 187        699
# 16          64
# 18         100
# 6.8        7.5
# 3.3        3.2
# 0.9       0.74
# 1            1
# Name: 0, dtype: object

# %% [markdown]
# # ADDING COLUMNS NAMES

# %% [markdown]
# Attribute Information:
#
# 1. Age Age of the patient
# 2. Gender Gender of the patient
# 3. TB Total Bilirubin
# 4. DB Direct Bilirubin
# 5. Alkphos Alkaline Phosphotase
# 6. Sgpt Alamine Aminotransferase
# 7. Sgot Aspartate Aminotransferase
# 8. TP Total Protiens
# 9. ALB Albumin
# 10. A/G Ratio Albumin and Globulin Ratio
# 11. Selector field used to split the data into two sets (labeled by the experts)

# %%
df.columns=['Age','Gender','TB','DB','Alkphos','Sgpt','Sgot','TP','ALB','A/G Ratio' ,'Selector field']

# %%
df.head(5)
# Out:
#    Age Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  \
# 0   62   Male  10.9  5.5      699    64   100  7.5  3.2       0.74
# 1   62   Male   7.3  4.1      490    60    68  7.0  3.3       0.89
# 2   58   Male   1.0  0.4      182    14    20  6.8  3.4       1.00
# 3   72   Male   3.9  2.0      195    27    59  7.3  2.4       0.40
# 4   46   Male   1.8  0.7      208    19    14  7.6  4.4       1.30
#
#    Selector field
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.isnull().sum()
# Out:
# Age               0
# Gender            0
# TB                0
# DB                0
# Alkphos           0
# Sgpt              0
# Sgot              0
# TP                0
# ALB               0
# A/G Ratio         4
# Selector field    0
# dtype: int64

# %%
df['A/G Ratio'].mean()
# Out:
# 0.9471453287197237

# %%
df=df.fillna(0.94)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# No data is missing

# %%
df.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  582.000000  582.000000  582.000000   582.000000   582.000000
# mean    44.711340    3.303265    1.488488   290.754296    80.824742
# std     16.181921    6.213926    2.810324   243.108929   182.757696
# min      4.000000    0.400000    0.100000    63.000000    10.000000
# 25%     33.000000    0.800000    0.200000   175.250000    23.000000
# 50%     45.000000    1.000000    0.300000   208.000000    35.000000
# 75%     57.750000    2.600000    1.300000   298.000000    60.750000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#               Sgot          TP         ALB   A/G Ratio  Selector field
# count   582.000000  582.000000  582.000000  582.000000      582.000000
# mean    110.068729    6.482646    3.141581    0.947096        1.286942
# std     289.141876    1.086306    0.796176    0.318760        0.452723
# min      10.000000    2.700000    0.900000    0.300000        1.000000
# 25%      25.000000    5.800000    2.600000    0.700000        1.000000
# 50%      42.000000    6.600000    3.100000    0.940000        1.000000
# 75%      87.000000    7.200000    3.800000    1.100000        2.000000
# max    4929.000000    9.600000    5.500000    2.800000        2.000000

# %%
corr=df[::][df.columns[:10]].corr()

# %%
ax=plt.subplots(figsize=(9,5))
ax=sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,annot=True)
ax.set_title('Correlation matrix', fontsize=16, fontdict={})
# Out:
# Text(0.5, 1, 'Correlation matrix')

# %%
sns.countplot(x='Gender',data=df)

# %%
sns.countplot(x='Selector field',data=df)

# %%
sns.factorplot(x="Age", y="Gender", hue="Selector field", data=df)
# Out:
# G:\Anacoda\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
def partition(x):
    if x =='Male':
        return 0
    return 1

df['Gender'] = df['Gender'].map(partition)

# %%
sns.pairplot(df)

# %%
df = pd.concat([df,pd.get_dummies(df['Gender'], prefix = 'Gender')], axis=1)
def convertSF(x):
    if x ==1:
        return 0
    return 1

df['Selector field'] = df['Selector field'].map(convertSF)

# %%
df.head()
# Out:
#    Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  \
# 0   62       0  10.9  5.5      699    64   100  7.5  3.2       0.74
# 1   62       0   7.3  4.1      490    60    68  7.0  3.3       0.89
# 2   58       0   1.0  0.4      182    14    20  6.8  3.4       1.00
# 3   72       0   3.9  2.0      195    27    59  7.3  2.4       0.40
# 4   46       0   1.8  0.7      208    19    14  7.6  4.4       1.30
#
#    Selector field  Gender_0  Gender_1
# 0               0         1         0
# 1               0         1         0
# 2               0         1         0
# 3               0         1         0
# 4               0         1         0

# %% [markdown]
# # BUILDING SVM MODEL

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import  confusion_matrix,classification_report,accuracy_score
from sklearn.svm import SVC
from sklearn import svm

# %%
y = df['Selector field']
X = df.drop(['Selector field','Gender'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,train_size=0.8, random_state=123,stratify=df['Selector field'])

# %%
train_mean = X_train.mean()
train_std = X_train.std()

# %%
X_train = (X_train - train_mean) / train_std
X_test = (X_test - train_mean) / train_std

# %%
X_test.describe()
# Out:
#               Age          TB          DB     Alkphos        Sgpt        Sgot  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean    -0.029828    0.007941    0.051844   -0.050669   -0.043502   -0.051665
# std      0.992034    0.887539    1.136866    0.789411    0.750406    0.576899
# min     -2.269270   -0.439472   -0.497555   -0.772109   -0.378704   -0.325925
# 25%     -0.789657   -0.392270   -0.460970   -0.447978   -0.316021   -0.277662
# 50%     -0.049851   -0.360801   -0.387800   -0.364969   -0.242891   -0.229400
# 75%      0.813257   -0.077588   -0.058536    0.018455   -0.117525   -0.110351
# max      1.861316    4.327959    6.160904    5.244084    6.098535    3.013871
#
#                TP         ALB   A/G Ratio    Gender_0    Gender_1
# count  117.000000  117.000000  117.000000  117.000000  117.000000
# mean    -0.166598   -0.163988   -0.140838   -0.143563    0.143563
# std      0.977547    0.926383    0.868404    1.082203    1.082203
# min     -3.504939   -2.811974   -1.795119   -1.827183   -0.546113
# 25%     -0.659976   -0.828369   -0.784809   -1.827183   -0.546113
# 50%     -0.109338   -0.084517   -0.172500    0.546113   -0.546113
# 75%      0.533073    0.535360    0.133655    0.546113    1.827183
# max      1.909668    1.899089    2.582891    0.546113    1.827183

# %%
X_train.describe()
# Out:
#                 Age            TB            DB       Alkphos          Sgpt  \
# count  4.650000e+02  4.650000e+02  4.650000e+02  4.650000e+02  4.650000e+02
# mean  -2.308786e-16 -2.043765e-16 -4.698750e-16  5.409353e-17 -6.834437e-18
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.515872e+00 -4.552060e-01 -4.975552e-01 -9.104579e-01 -3.787039e-01
# 25%   -7.280065e-01 -3.922696e-01 -4.609703e-01 -4.677420e-01 -3.055738e-01
# 50%    1.179978e-02 -3.608014e-01 -4.243853e-01 -3.333461e-01 -2.481144e-01
# 75%    7.516061e-01 -1.247900e-01 -9.512085e-02 -1.309106e-03 -1.123014e-01
# max    2.786073e+00  1.128243e+01  6.673093e+00  7.180966e+00  1.001622e+01
#
#                Sgot            TP           ALB     A/G Ratio      Gender_0  \
# count  4.650000e+02  4.650000e+02  4.650000e+02  4.650000e+02  4.650000e+02
# mean   1.596692e-17 -4.370697e-15 -3.729394e-16 -5.099863e-16  1.093510e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.323605e-01 -3.413166e+00 -2.811974e+00 -2.009427e+00 -1.827183e+00
# 25%   -2.840975e-01 -6.599760e-01 -7.043933e-01 -7.848090e-01  5.461135e-01
# 50%   -2.293995e-01  7.420783e-02 -8.451654e-02  1.336546e-01  5.461135e-01
# 75%   -8.139314e-02  6.248457e-01  9.072864e-01  4.398091e-01  5.461135e-01
# max    1.549467e+01  2.827397e+00  2.890892e+00  5.644436e+00  5.461135e-01
#
#            Gender_1
# count  4.650000e+02
# mean  -1.093510e-16
# std    1.000000e+00
# min   -5.461135e-01
# 25%   -5.461135e-01
# 50%   -5.461135e-01
# 75%   -5.461135e-01
# max    1.827183e+00

# %%
model = SVC(C=1.0,gamma=1.0)
model.fit(X_train,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1.0, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print("SVM Score is: {}" .format(float("{:.2f}".format(model.score(X_test, y_test) * 100))))
# Out:
# SVM Score is: 66.67

# %%
y_train_pred=model.predict(X_train)
y_pred = model.predict(X_test)

# %%
confusion_matrix(y_test,y_pred).T
# Out:
# array([[75, 31],
#        [ 8,  3]], dtype=int64)
